# %% [markdown]
# # Extract a dataframe of PubMed articles from efetch XML results

# %%
import collections
import itertools
import pathlib
import pandas
from pubmedpy.xml import iter_extract_elems
from pubmedpy.efetch import extract_all

# %%
# Create a generator of XML PubmedArticle elements
article_elems = itertools.chain.from_iterable(
    iter_extract_elems(path, tag='PubmedArticle')
#     for path in sorted(pathlib.Path('data/pubmed/efetch').glob('*.xml.xz'))
    for path in sorted(pathlib.Path('data/pubmed/efetch').glob('compbio.xml.xz'))
)

# %%
articles = list()
for elem in article_elems:
    # Example efetch XML for <PubmedArticle> at https://github.com/dhimmel/pubmedpy/blob/f554a06e13e24d661dc5ff93ad07179fb3d7f0af/pubmedpy/data/efetch.xml
    articles.append(extract_all(elem))
len(articles)
# Out:
# 180761

# %%
article_df = pandas.DataFrame(articles)
article_df.pmid = article_df.pmid.astype(int)
article_df = article_df.sort_values('pmid')
article_df.sample(n=20, random_state=0).sort_values('pmid')
# Out:
#             pmid       pmcid                               doi  \
# 15852   16026357        None  10.1111/j.1365-2052.2005.01324.x
# 26654   17418445        None         10.1016/j.tig.2007.03.008
# 33022   18334116        None                              None
# 33860   18428815        None      10.1002/0471142700.nca04as00
# 53858   20618438        None  10.1111/j.1742-4658.2010.07727.x
# 61338   21406205        None     10.1016/j.jconrel.2011.03.008
# 61929   21453479  PMC3094196            10.1186/1755-8794-4-28
# 88241   23806673        None   10.1016/j.marpolbul.2013.05.042
# 94138   24344193        None     10.1093/bioinformatics/btt722
# 112634  25974149        None            10.1001/jama.2015.5533
# 116142  26296590        None      10.1016/j.vetpar.2015.07.031
# 118545  26476368  PMC4773399       10.1016/j.ymeth.2015.10.006
# 120219  26602686  PMC4702873               10.1093/nar/gkv1233
# 123185  26851080        None         10.1016/j.aca.2015.12.042
# 142416  28526946        None         10.1007/s10886-017-0850-z
# 150827  29196697  PMC5711952        10.1038/s41598-017-15911-7
# 166357  30476167        None             10.1093/jhered/esy064
# 171957  30947440        None               10.3934/mbe.2019082
# 174923  31205958  PMC6530242              10.1155/2019/6720819
# 176172  31323060  PMC6641209      10.1371/journal.pone.0219976
#
#                               journal journal_nlm_id  \
# 15852                      Anim Genet        8605704
# 26654                    Trends Genet        8507085
# 33022                        Ai Zheng        9424852
# 33860   Curr Protoc Nucleic Acid Chem      101287865
# 53858                          FEBS J      101229646
# 61338               J Control Release        8607908
# 61929                BMC Med Genomics      101319628
# 88241                 Mar Pollut Bull        0260231
# 94138                  Bioinformatics        9808944
# 112634                           JAMA        7501160
# 116142                  Vet Parasitol        7602745
# 118545                        Methods        9426302
# 120219              Nucleic Acids Res        0411011
# 123185                 Anal Chim Acta        0370534
# 142416                    J Chem Ecol        7505563
# 150827                        Sci Rep      101563288
# 166357                        J Hered        0375373
# 171957                Math Biosci Eng      101197794
# 174923                  J Immunol Res      101627166
# 176172                       PLoS One      101285081
#
#                                                     title publication_date  \
# 15852   Assignment porcine PCK1 and PCK2 genes to SSC1...          2005-08
# 26654   Positive and negative selection on the mitocho...       2007-04-05
# 33022   [Serum proteomic spectra of esophageal squamou...          2008-03
# 33860            Useful nucleic acid chemistry web sites.          2001-05
# 53858   N-glycosylation is important for the correct i...       2010-07-05
# 61338   Following dynamic biological processes through...       2011-03-22
# 61929   Immunological network signatures of cancer pro...       2011-03-31
# 88241   Genomics in marine monitoring: new opportuniti...       2013-06-24
# 94138   A hierarchical statistical modeling approach t...       2013-12-15
# 112634  Single molecules meet genomics: pinpointing pr...       2015-05-26
# 116142  Recent advances in Echinococcus genomics and s...       2015-07-31
# 118545  Metadata management for high content screening...       2015-10-22
# 120219  Developmental progress and current status of t...       2015-11-23
# 123185  Chromatographic fingerprinting: An innovative ...       2016-01-08
# 142416  Evolutionary Ecology of Multitrophic Interacti...       2017-05-19
# 150827  De novo transcriptome assembly of Zanthoxylum ...       2017-12-01
# 166357  Phylogenetic Relationships and Evolutionary Tr...       2019-01-07
# 171957  The density-based clustering method for privac...       2019-02-27
# 174923                                    Circulating CD3       2019-05-08
# 176172  Comparative transcriptome analysis of transluc...       2019-07-19
#
#                                                   authors
# 15852   [{'fore_name': 'Y', 'last_name': 'Peng', 'affi...
# 26654   [{'fore_name': 'Colin D', 'last_name': 'Meikle...
# 33022   [{'fore_name': 'Cha-Zhen', 'last_name': 'Liu',...
# 33860                                                  []
# 53858   [{'fore_name': 'Lavinia', 'last_name': 'Bhatt'...
# 61338   [{'fore_name': 'Iola F', 'last_name': 'Duarte'...
# 61929   [{'fore_name': 'Trevor', 'last_name': 'Clancy'...
# 88241   [{'fore_name': 'Sarah J', 'last_name': 'Bourla...
# 94138   [{'fore_name': 'Cong', 'last_name': 'Zhou', 'a...
# 112634  [{'fore_name': 'Xiaoliang Sunney', 'last_name'...
# 116142  [{'fore_name': 'U', 'last_name': 'Koziol', 'af...
# 118545  [{'fore_name': 'Simon', 'last_name': 'Li', 'af...
# 120219  [{'fore_name': 'Zhi-Liang', 'last_name': 'Hu',...
# 123185  [{'fore_name': 'Luis', 'last_name': 'Cuadros-R...
# 142416  [{'fore_name': 'Ikkei', 'last_name': 'Shikano'...
# 150827  [{'fore_name': 'Shijing', 'last_name': 'Feng',...
# 166357  [{'fore_name': 'Pablo C', 'last_name': 'Guerre...
# 171957  [{'fore_name': 'Jimmy Ming-Tai', 'last_name': ...
# 174923  [{'fore_name': 'Ryutaro', 'last_name': 'Oba', ...
# 176172  [{'fore_name': 'Deden Derajat', 'last_name': '...

# %%
author_rows = list()
affiliation_rows = list()
for pmid, authors in zip(article_df.pmid, article_df.authors):
    for i, author in enumerate(authors):
        row_template = {'pmid': pmid, 'position': i + 1}
        row = row_template.copy()
        row.update(author)
        row['reverse_position'] = len(authors) - i
        for affiliation in row.pop('affiliations'):
            affiliation_rows.append(
                {**row_template, "affiliation": affiliation}
            )
        author_rows.append(row)
author_df = pandas.DataFrame(author_rows)
author_df = author_df.sort_values(['pmid', 'position'])
author_df.head()
# Out:
#       pmid  position fore_name last_name  reverse_position
# 0  7477412         1       A H     Samad                10
# 1  7477412         2       W W       Cai                 9
# 2  7477412         3         X        Hu                 8
# 3  7477412         4         B     Irvin                 7
# 4  7477412         5         J      Jing                 6

# %%
affiliation_df = pandas.DataFrame(affiliation_rows)
affiliation_df = affiliation_df.sort_values(['pmid', 'position'])
affiliation_df.head()
# Out:
#       pmid  position                                        affiliation
# 0  7477412         1  Dept. of Pathology, Cornell Medical College, N...
# 1  7479891         1  National Center for Human Genome Research, Nat...
# 2  7479895         1  National Center for Human Genome Research, Nat...
# 3  7480790         1  Computation Center, Institute of Physical and ...
# 4  7497116         1  Sandia National Labs, Albuquerque, New Mexico ...

# %%
# Number of unique affiliations
affiliation_df.affiliation.nunique()
# Out:
# 386461

# %%
# Write article dataframe to TSV
(
    article_df
    [['pmid', 'pmcid', 'doi', 'journal', 'publication_date', 'title']]
    .to_csv('data/pubmed/articles.tsv.xz', sep='\t', index=False)
)
# Write author dataframe to TSV
author_df.to_csv('data/pubmed/authors.tsv.xz', sep='\t', index=False)

# Write affiliation dataframe to TSV
affiliation_df.to_csv('data/pubmed/affiliations.tsv.xz', sep='\t', index=False)

# %%
# PubMed articles in PMC by journal
article_df.journal.value_counts()
# Out:
# PLoS One                            7755
# Methods Mol Biol                    5440
# Bioinformatics                      5064
# J Proteome Res                      4319
# BMC Genomics                        4086
#                                     ...
# J Card Surg                            1
# Arch Ital Urol Androl                  1
# Skinmed                                1
# Vasc Med                               1
# Arch Dis Child Fetal Neonatal Ed       1
# Name: journal, Length: 4547, dtype: int64

# %%
# PubMed articles in PMC by journal
pandas.crosstab(article_df.pmcid.notna(), article_df.journal)
# Out:
# journal  A A Case Rep  AACN Adv Crit Care  AACN Clin Issues  AAOHN J  AAPS J  \
# pmcid
# False               1                   6                 1        1       5
# True                0                   0                 1        0      24
#
# journal  AAPS PharmSci  ABNF J  ACS Appl Mater Interfaces  ACS Chem Biol  \
# pmcid
# False                1       0                         10             89
# True                 2       1                          1             84
#
# journal  ACS Chem Neurosci  ...  Zoo Biol  Zool Res  Zoolog Sci  \
# pmcid                       ...
# False                    8  ...         2         0          15
# True                    17  ...         0         4           0
#
# journal  Zoology (Jena)  Zoonoses Public Health  Zootaxa  Zygote  eNeuro  \
# pmcid
# False                 1                       2        9       2       0
# True                  0                       0        0       0       8
#
# journal  mBio  mSphere
# pmcid
# False       0        0
# True      204       37
#
# [2 rows x 4547 columns]

# %%
# articles without a publication date
article_df[article_df.publication_date.isna()]
# Out:
#             pmid       pmcid                        doi  \
# 8        7510179        None                       None
# 9        7510181        None                       None
# 10       7513103        None                       None
# 40       7764291        None                       None
# 41       7764293        None                       None
# ...          ...         ...                        ...
# 180098  31802060        None                       None
# 180120  31808361  PMC6900616   10.1177/1533033819892260
# 180538  31876272        None  10.1134/s0026898419060156
# 180662  31898667        None   10.4103/jcrt.jcrt_866_18
# 180739  32053766        None                       None
#
#                          journal journal_nlm_id  \
# 8       Vestn Ross Akad Med Nauk        9215641
# 9       Vestn Ross Akad Med Nauk        9215641
# 10                Turk J Pediatr        0417505
# 40          Australas Biotechnol        9113681
# 41          Australas Biotechnol        9113681
# ...                          ...            ...
# 180098           Hell J Nucl Med      101257471
# 180120  Technol Cancer Res Treat      101140941
# 180538           Mol Biol (Mosk)        0105454
# 180662         J Cancer Res Ther      101249598
# 180739                Discov Med      101250006
#
#                                                     title publication_date  \
# 8       [Molecular diagnosis of genetic diseases in Ru...             None
# 9       [Administration, maintenance and expression of...             None
# 10      Child health, the genome project and phenylket...             None
# 40               Some ethical issues in genetic medicine.             None
# 41                  Legal rights and genetic engineering.             None
# ...                                                   ...              ...
# 180098  Predicting oligonucleotide therapeutic efficac...             None
# 180120  Bioinformatics Analysis of Expression and Alte...             None
# 180538                                     [3D Genomics].             None
# 180662  Regulation of HMGA2 and KRAS genes in epitheli...             None
# 180739  Translating cancer genomics for precision onco...             None
#
#                                                   authors
# 8       [{'fore_name': 'V S', 'last_name': 'Baranov', ...
# 9       [{'fore_name': 'V I', 'last_name': 'Ivanov', '...
# 10      [{'fore_name': 'C R', 'last_name': 'Scriver', ...
# 40      [{'fore_name': 'N A', 'last_name': 'Tonti-Fili...
# 41      [{'fore_name': 'N', 'last_name': 'Stoianoff', ...
# ...                                                   ...
# 180098  [{'fore_name': 'Pantazis I', 'last_name': 'The...
# 180120  [{'fore_name': 'Yong-Zi', 'last_name': 'Chen',...
# 180538  [{'fore_name': 'S V', 'last_name': 'Razin', 'a...
# 180662  [{'fore_name': 'Tuba', 'last_name': 'Gunel', '...
# 180739  [{'fore_name': 'Philipp K', 'last_name': 'Habe...
#
# [3211 rows x 8 columns]

# %%
# article proportions by date precision
article_df.publication_date.str.len().value_counts()
# Out:
# 10.0    136245
# 7.0      27273
# 4.0      14032
# Name: publication_date, dtype: int64
