# %% [markdown]
# # Extract a dataframe of PubMed articles from efetch XML results

# %%
import collections
import itertools
import pathlib
import pandas
from pubmedpy.xml import iter_extract_elems
from pubmedpy.efetch import extract_all

# %%
# Create a generator of XML PubmedArticle elements
article_elems = itertools.chain.from_iterable(
    iter_extract_elems(path, tag='PubmedArticle')
#     for path in sorted(pathlib.Path('data/pubmed/efetch').glob('*.xml.xz'))
    for path in sorted(pathlib.Path('data/pubmed/efetch').glob('compbio-english.xml.xz'))
)

# %%
articles = list()
for elem in article_elems:
    # Example efetch XML for <PubmedArticle> at https://github.com/dhimmel/pubmedpy/blob/f554a06e13e24d661dc5ff93ad07179fb3d7f0af/pubmedpy/data/efetch.xml
    articles.append(extract_all(elem))
len(articles)
# Out:
# 177262

# %%
article_df = pandas.DataFrame(articles)
article_df.pmid = article_df.pmid.astype(int)
article_df = article_df.sort_values('pmid')
article_df.sample(n=20, random_state=0).sort_values('pmid')
# Out:
#             pmid       pmcid                            doi  \
# 7138    14580578        None   10.1016/j.copbio.2003.08.001
# 8766    15059992   PMC383295             10.1101/gr.1984404
# 11513   15562315   PMC532387   10.1371/journal.pbio.0020412
# 15511   16097032        None         10.1002/pmic.200401215
# 25883   17453953        None      10.1080/02713680701215322
# 27922   17705782        None     10.1162/evco.2007.15.3.345
# 32634   18436738  PMC2518900   10.1182/blood-2007-07-099432
# 56354   21124818  PMC2991263   10.1371/journal.ppat.1001211
# 59270   21388834        None   10.1016/j.concog.2011.02.010
# 72594   22635606  PMC3400962  10.1093/bioinformatics/bts315
# 77192   23050228  PMC3464110          10.1534/g3.112.003822
# 82122   23494000  PMC3857698         10.1001/jama.2013.1579
# 82885   23555834  PMC3612055   10.1371/journal.pone.0059926
# 98909   25033057  PMC6270779     10.3390/molecules190710291
# 115090  26435515        None               10.1002/psc.2824
# 115773  26489431  PMC4614854              10.1038/srep15654
# 116696  26560501  PMC4642335              10.1038/srep16401
# 117561  26629978  PMC6020058  10.1021/acs.jproteome.5b00610
# 125697  27341029  PMC4920351   10.1371/journal.pone.0158167
# 153352  29678131  PMC5910624      10.1186/s12859-018-2134-1
#
#                      journal journal_nlm_id  \
# 7138    Curr Opin Biotechnol        9100492
# 8766              Genome Res        9518021
# 11513              PLoS Biol      101183755
# 15511             Proteomics      101092707
# 25883           Curr Eye Res        8104312
# 27922            Evol Comput        9513581
# 32634                  Blood        7603509
# 56354            PLoS Pathog      101238921
# 59270         Conscious Cogn        9303140
# 72594         Bioinformatics        9808944
# 77192          G3 (Bethesda)      101566598
# 82122                   JAMA        7501160
# 82885               PLoS One      101285081
# 98909              Molecules      100964009
# 115090            J Pept Sci        9506309
# 115773               Sci Rep      101563288
# 116696               Sci Rep      101563288
# 117561        J Proteome Res      101128775
# 125697              PLoS One      101285081
# 153352    BMC Bioinformatics      100965194
#
#                                                     title publication_date  \
# 7138                   Advances in flux balance analysis.          2003-10
# 8766    Patterns of insertions and their covariation w...          2004-04
# 11513   In silico reconstitution of Listeria propulsio...       2004-11-30
# 15511   Subproteomic analysis of metal-interacting pro...          2005-09
# 25883   Feasibility of two-dimensional gel electrophor...          2007-04
# 27922   A new approach of data clustering using a floc...             2007
# 32634   Genomic complexity identifies patients with ag...       2008-04-24
# 56354   Glycosylation focuses sequence variation in th...       2010-11-24
# 59270       Towards a computational theory of experience.       2011-03-08
# 72594   Gowinda: unbiased analysis of gene set enrichm...       2012-05-26
# 77192   A fast and efficient approach for genomic sele...       2012-10-01
# 82122   Crossing the omic chasm: a time for omic ancil...       2013-03-27
# 82885   Identification and functional analysis of GJA8...       2013-03-29
# 98909   Biotransformation and in vitro metabolic profi...       2014-07-16
# 115090  Rational design of YAP WW1 domain-binding pept...       2015-10-05
# 115773  Increased male fertility using fertility-relat...       2015-10-22
# 116696  A Systems Biology-Based Investigation into the...       2015-11-12
# 117561  SpectroGene: A Tool for Proteogenomic Annotati...       2015-12-17
# 125697  Comparative Mt Genomics of the Tipuloidea (Dip...       2016-06-24
# 153352  SECIMTools: a suite of metabolomics data analy...       2018-04-20
#
#                                                   authors
# 7138    [{'fore_name': 'Kenneth J', 'last_name': 'Kauf...
# 8766    [{'fore_name': 'Shan', 'last_name': 'Yang', 'a...
# 11513   [{'fore_name': 'Jonathan B', 'last_name': 'Alb...
# 15511   [{'fore_name': 'Kirsten', 'last_name': 'Heiss'...
# 25883   [{'fore_name': 'Fan', 'last_name': 'Lu', 'affi...
# 27922   [{'fore_name': 'Fabien', 'last_name': 'Picarou...
# 32634   [{'fore_name': 'Lisa', 'last_name': 'Kujawski'...
# 56354   [{'fore_name': 'Suman R', 'last_name': 'Das', ...
# 59270   [{'fore_name': 'Tomer', 'last_name': 'Fekete',...
# 72594   [{'fore_name': 'Robert', 'last_name': 'Kofler'...
# 77192   [{'fore_name': 'Vitara', 'last_name': 'Pungpap...
# 82122   [{'fore_name': 'Justin', 'last_name': 'Starren...
# 82885   [{'fore_name': 'Dongmei', 'last_name': 'Su', '...
# 98909   [{'fore_name': 'Chi-Yu', 'last_name': 'He', 'a...
# 115090  [{'fore_name': 'Dong', 'last_name': 'Chen', 'a...
# 115773  [{'fore_name': 'Woo-Sung', 'last_name': 'Kwon'...
# 116696  [{'fore_name': 'Lin', 'last_name': 'Huang', 'a...
# 117561  [{'fore_name': 'Mikhail', 'last_name': 'Kolmog...
# 125697  [{'fore_name': 'Xiao', 'last_name': 'Zhang', '...
# 153352  [{'fore_name': 'Alexander S', 'last_name': 'Ki...

# %%
author_rows = list()
affiliation_rows = list()
for pmid, authors in zip(article_df.pmid, article_df.authors):
    for i, author in enumerate(authors):
        row_template = {'pmid': pmid, 'position': i + 1}
        row = row_template.copy()
        row.update(author)
        row['reverse_position'] = len(authors) - i
        for affiliation in row.pop('affiliations'):
            affiliation_rows.append(
                {**row_template, "affiliation": affiliation}
            )
        author_rows.append(row)
author_df = pandas.DataFrame(author_rows)
author_df = author_df.sort_values(['pmid', 'position'])
author_df.head()
# Out:
#       pmid  position fore_name last_name  reverse_position
# 0  7477412         1       A H     Samad                10
# 1  7477412         2       W W       Cai                 9
# 2  7477412         3         X        Hu                 8
# 3  7477412         4         B     Irvin                 7
# 4  7477412         5         J      Jing                 6

# %%
affiliation_df = pandas.DataFrame(affiliation_rows)
affiliation_df = affiliation_df.sort_values(['pmid', 'position'])
affiliation_df.head()
# Out:
#       pmid  position                                        affiliation
# 0  7477412         1  Dept. of Pathology, Cornell Medical College, N...
# 1  7479891         1  National Center for Human Genome Research, Nat...
# 2  7479895         1  National Center for Human Genome Research, Nat...
# 3  7497116         1  Sandia National Labs, Albuquerque, New Mexico ...
# 4  7497128         1  Sandia National Laboratories, Albuquerque, NM ...

# %%
# Number of unique affiliations
affiliation_df.affiliation.nunique()
# Out:
# 383954

# %%
# Write article dataframe to TSV
(
    article_df
    [['pmid', 'pmcid', 'doi', 'journal', 'publication_date', 'title']]
    .to_csv('data/pubmed/articles.tsv.xz', sep='\t', index=False)
)
# Write author dataframe to TSV
author_df.to_csv('data/pubmed/authors.tsv.xz', sep='\t', index=False)

# Write affiliation dataframe to TSV
affiliation_df.to_csv('data/pubmed/affiliations.tsv.xz', sep='\t', index=False)

# %%
# PubMed articles in PMC by journal
article_df.journal.value_counts()
# Out:
# PLoS One                 7755
# Methods Mol Biol         5440
# Bioinformatics           5073
# J Proteome Res           4319
# BMC Genomics             4086
#                          ...
# Environ Biosafety Res       1
# Surg Innov                  1
# J Stem Cells                1
# Pain Manag                  1
# Nurs Sci Q                  1
# Name: journal, Length: 4286, dtype: int64

# %%
# PubMed articles in PMC by journal
pandas.crosstab(article_df.pmcid.notna(), article_df.journal)
# Out:
# journal  A A Case Rep  AACN Adv Crit Care  AACN Clin Issues  AAOHN J  AAPS J  \
# pmcid
# False               1                   6                 1        1       5
# True                0                   0                 1        0      24
#
# journal  AAPS PharmSci  ABNF J  ACS Appl Mater Interfaces  ACS Chem Biol  \
# pmcid
# False                1       0                         10             89
# True                 2       1                          1             84
#
# journal  ACS Chem Neurosci  ...  Zoo Biol  Zool Res  Zoolog Sci  \
# pmcid                       ...
# False                    8  ...         2         0          15
# True                    17  ...         0         4           0
#
# journal  Zoology (Jena)  Zoonoses Public Health  Zootaxa  Zygote  eNeuro  \
# pmcid
# False                 1                       2        9       2       0
# True                  0                       0        0       0       8
#
# journal  mBio  mSphere
# pmcid
# False       0        0
# True      204       37
#
# [2 rows x 4286 columns]

# %%
# articles without a publication date
article_df[article_df.publication_date.isna()]
# Out:
#             pmid       pmcid                                 doi  \
# 7        7513103        None                                None
# 34       7764291        None                                None
# 35       7764293        None                                None
# 54       7856962        None                                None
# 62       7965253        None  10.1111/j.1552-6909.1994.tb01909.x
# ...          ...         ...                                 ...
# 175822  31684829  PMC6831968            10.1177/1533033819883633
# 176608  31802060        None                                None
# 176630  31808361  PMC6900616            10.1177/1533033819892260
# 177166  31898667        None            10.4103/jcrt.jcrt_866_18
# 177242  32053766        None                                None
#
#                                journal journal_nlm_id  \
# 7                       Turk J Pediatr        0417505
# 34                Australas Biotechnol        9113681
# 35                Australas Biotechnol        9113681
# 54                            Am Nurse        7506499
# 62      J Obstet Gynecol Neonatal Nurs        8503123
# ...                                ...            ...
# 175822        Technol Cancer Res Treat      101140941
# 176608                 Hell J Nucl Med      101257471
# 176630        Technol Cancer Res Treat      101140941
# 177166               J Cancer Res Ther      101249598
# 177242                      Discov Med      101250006
#
#                                                     title publication_date  \
# 7       Child health, the genome project and phenylket...             None
# 34               Some ethical issues in genetic medicine.             None
# 35                  Legal rights and genetic engineering.             None
# 54      Survey assesses RN management of genetic infor...             None
# 62                                    The genome project.             None
# ...                                                   ...              ...
# 175822  Long Noncoding RNA GM16343 Promotes IL-36β to ...             None
# 176608  Predicting oligonucleotide therapeutic efficac...             None
# 176630  Bioinformatics Analysis of Expression and Alte...             None
# 177166  Regulation of HMGA2 and KRAS genes in epitheli...             None
# 177242  Translating cancer genomics for precision onco...             None
#
#                                                   authors
# 7       [{'fore_name': 'C R', 'last_name': 'Scriver', ...
# 34      [{'fore_name': 'N A', 'last_name': 'Tonti-Fili...
# 35      [{'fore_name': 'N', 'last_name': 'Stoianoff', ...
# 54      [{'fore_name': 'C', 'last_name': 'Scanlon', 'a...
# 62      [{'fore_name': 'B S', 'last_name': 'Raff', 'af...
# ...                                                   ...
# 175822  [{'fore_name': 'Deli', 'last_name': 'Mao', 'af...
# 176608  [{'fore_name': 'Pantazis I', 'last_name': 'The...
# 176630  [{'fore_name': 'Yong-Zi', 'last_name': 'Chen',...
# 177166  [{'fore_name': 'Tuba', 'last_name': 'Gunel', '...
# 177242  [{'fore_name': 'Philipp K', 'last_name': 'Habe...
#
# [2860 rows x 8 columns]

# %%
# article proportions by date precision
article_df.publication_date.str.len().value_counts()
# Out:
# 10.0    135844
# 7.0      24805
# 4.0      13753
# Name: publication_date, dtype: int64
