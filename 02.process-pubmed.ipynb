# %% [markdown]
# # Extract a dataframe of PubMed articles from efetch & esummary XML results

# %%
import collections
import itertools
import pathlib
import pandas
from pubmedpy.xml import iter_extract_elems
from pubmedpy.efetch import extract_all
from pubmedpy.esummary import parse_esummary_article_info

# %% [markdown]
# ### Load incoming citation counts from esummary records

# %%
docsums = list()
# generator of XML PubmedArticle elements
docsum_elems = iter_extract_elems('data/pubmed/esummary/compbio-english.xml.xz', tag='DocSum')
for elem in docsum_elems:
    # Example esummary XML for <DocSum> at https://github.com/dhimmel/pubmedpy/blob/f554a06e13e24d661dc5ff93ad07179fb3d7f0af/pubmedpy/data/esummary.xml
    docsums.append(parse_esummary_article_info(elem))
len(docsums)
# Out:
# 179656

# %%
citation_count_df = (
    pandas.DataFrame(docsums)
    .rename(columns={"pubmed_id": "pmid"})
    [["pmid", "pmc_cited_by_count"]]
)
citation_count_df.head(2)
# Out:
#       pmid  pmc_cited_by_count
# 0  7477412                   2
# 1  7479891                   4

# %% [markdown]
# ### Load article information from efetch records

# %%
articles = list()
# generator of XML PubmedArticle elements
article_elems = iter_extract_elems('data/pubmed/efetch/compbio-english.xml.xz', tag='PubmedArticle')
for elem in article_elems:
    # Example efetch XML for <PubmedArticle> at https://github.com/dhimmel/pubmedpy/blob/f554a06e13e24d661dc5ff93ad07179fb3d7f0af/pubmedpy/data/efetch.xml
    articles.append(extract_all(elem))
len(articles)
# Out:
# 179656

# %%
article_df = pandas.DataFrame(articles)
article_df.pmid = article_df.pmid.astype(int)
article_df = article_df.merge(citation_count_df, how="left")
article_df = article_df.sort_values('pmid')
article_df.sample(n=20, random_state=0).sort_values('pmid')
# Out:
#             pmid       pmcid                              doi  \
# 2211    11448876        None  10.1093/bioinformatics/17.7.581
# 9983    15266247  PMC1395763                             None
# 15488   16094372        None              10.1038/nature03869
# 19362   16615769        None                10.1021/ac051639u
# 51674   20566863  PMC2901460          10.1073/pnas.1003379107
# 61206   21569439  PMC3107185         10.1186/1471-2164-12-237
# 73946   22761568  PMC3386159     10.1371/journal.pcbi.1002590
# 83154   23576030        None           10.1002/elps.201200710
# 89965   24187136  PMC3861660          10.1074/jbc.m113.507285
# 92226   24405844  PMC3890554           10.1186/1471-2350-15-6
# 93470   24524683        None                10.1021/ja410678y
# 96377   24798176        None         10.1177/1062860614532517
# 100183  25146848        None        10.1007/s12035-014-8867-6
# 107414  25765008        None     10.1016/j.artmed.2014.12.012
# 119498  26797767  PMC4761715            10.18632/aging.100874
# 130529  27801294  PMC5088516        10.1186/s12864-016-3064-9
# 139992  28595569  PMC5465541        10.1186/s12864-017-3841-0
# 140387  28627464        None      10.1016/j.jprot.2017.06.004
# 146917  29149287  PMC5909424            10.1093/dnares/dsx046
# 160837  30311980        None                 10.1113/ep087159
#
#                          journal journal_nlm_id  \
# 2211              Bioinformatics        9808944
# 9983                   MedGenMed      100894134
# 15488                     Nature        0410462
# 19362                  Anal Chem        0370536
# 51674   Proc Natl Acad Sci U S A        7505876
# 61206               BMC Genomics      100965258
# 73946           PLoS Comput Biol      101238922
# 83154            Electrophoresis        8204476
# 89965                J Biol Chem       2985121R
# 92226              BMC Med Genet      100968552
# 93470              J Am Chem Soc        7503056
# 96377              Am J Med Qual        9300756
# 100183             Mol Neurobiol        8900963
# 107414          Artif Intell Med        8915031
# 119498         Aging (Albany NY)      101508617
# 130529              BMC Genomics      100965258
# 139992              BMC Genomics      100965258
# 140387              J Proteomics      101475056
# 146917                   DNA Res        9423827
# 160837               Exp Physiol        9002940
#
#                                                     title publication_date  \
# 2211    LDB2000: sequence-based integrated maps of the...          2001-07
# 9983    Conference report--genomics: the promise of SN...       2004-04-19
# 15488   Identification of JAK/STAT signalling componen...       2005-08-11
# 19362   Correlation and convolution analysis of peptid...       2006-04-15
# 51674   Genome sequences of the human body louse and i...       2010-06-21
# 61206   Genome-level homology and phylogeny of Shewane...       2011-05-12
# 73946   Learning with slight forgetting optimizes sens...       2012-06-28
# 83154         Phosphoproteomics--more than meets the eye.       2013-05-14
# 89965   Inhibition of mitochondrial pyruvate transport...       2013-11-01
# 92226   A novel MIP gene mutation associated with auto...       2014-01-09
# 93470   Mass spectrometric proteomics reveals that nuc...       2014-02-14
# 96377   Enhanced assessment of chest pain and related ...       2014-05-05
# 100183  Induced Pluripotent Stem Cells for Disease Mod...       2014-08-23
# 107414  Predicting protein complexes from weighted pro...       2015-02-18
# 119498  Metabolomics profiling reveals novel markers f...          2016-01
# 130529  Combined genomic and structural analyses of a ...       2016-10-25
# 139992  Genome-wide comparative transcriptome analysis...       2017-06-08
# 140387  Analysis of protein complexes in Arabidopsis l...       2017-06-13
# 146917  Genomic and epigenomic immunity in common bean...       2018-04-01
# 160837  Characterizing the plasma metabolome during 14...       2018-11-01
#
#                                                   authors  pmc_cited_by_count
# 2211    [{'fore_name': 'X', 'last_name': 'Ke', 'affili...                   6
# 9983    [{'fore_name': 'Sara M', 'last_name': 'Mariani...                   0
# 15488   [{'fore_name': 'Patrick', 'last_name': 'Müller...                 133
# 19362   [{'fore_name': 'Matthew J', 'last_name': 'Snia...                   1
# 51674   [{'fore_name': 'Ewen F', 'last_name': 'Kirknes...                 171
# 61206   [{'fore_name': 'Rebecca B', 'last_name': 'Diko...                  16
# 73946   [{'fore_name': 'Masaya', 'last_name': 'Hirashi...                   4
# 83154   [{'fore_name': 'Stefan', 'last_name': 'Loroch'...                   8
# 89965   [{'fore_name': 'Jianhai', 'last_name': 'Du', '...                  29
# 92226   [{'fore_name': 'Yibo', 'last_name': 'Yu', 'aff...                  13
# 93470   [{'fore_name': 'Zhifeng', 'last_name': 'Du', '...                   6
# 96377   [{'fore_name': 'Joseph A', 'last_name': 'Ladap...                   0
# 100183  [{'fore_name': 'Lei', 'last_name': 'Cao', 'aff...                  10
# 107414  [{'fore_name': 'Konstantinos', 'last_name': 'T...                   5
# 119498  [{'fore_name': 'Jonas', 'last_name': 'Zierer',...                   8
# 130529  [{'fore_name': 'Ana Carolina Vieira', 'last_na...                   5
# 139992  [{'fore_name': 'Jianyong', 'last_name': 'Wu', ...                   9
# 140387  [{'fore_name': 'Uma K', 'last_name': 'Aryal', ...                  16
# 146917  [{'fore_name': 'Manon M S', 'last_name': 'Rich...                   6
# 160837  [{'fore_name': 'Nathan G', 'last_name': 'Lawle...                   1

# %%
author_rows = list()
affiliation_rows = list()
for pmid, authors in zip(article_df.pmid, article_df.authors):
    for i, author in enumerate(authors):
        row_template = {'pmid': pmid, 'position': i + 1}
        row = row_template.copy()
        row.update(author)
        row['reverse_position'] = len(authors) - i
        for affiliation in row.pop('affiliations'):
            affiliation_rows.append(
                {**row_template, "affiliation": affiliation}
            )
        author_rows.append(row)
author_df = pandas.DataFrame(author_rows)
author_df = author_df.sort_values(['pmid', 'position'])
author_df.head()
# Out:
#       pmid  position fore_name last_name  reverse_position
# 0  7477412         1       A H     Samad                10
# 1  7477412         2       W W       Cai                 9
# 2  7477412         3         X        Hu                 8
# 3  7477412         4         B     Irvin                 7
# 4  7477412         5         J      Jing                 6

# %%
affiliation_df = pandas.DataFrame(affiliation_rows)
affiliation_df = affiliation_df.sort_values(['pmid', 'position'])
affiliation_df.head()
# Out:
#       pmid  position                                        affiliation
# 0  7477412         1  Dept. of Pathology, Cornell Medical College, N...
# 1  7479891         1  National Center for Human Genome Research, Nat...
# 2  7479895         1  National Center for Human Genome Research, Nat...
# 3  7497116         1  Sandia National Labs, Albuquerque, New Mexico ...
# 4  7497128         1  Sandia National Laboratories, Albuquerque, NM ...

# %%
# Number of unique affiliations
affiliation_df.affiliation.nunique()
# Out:
# 393612

# %%
# Write article dataframe to TSV
(
    article_df
    [['pmid', 'pmcid', 'doi', 'journal', 'publication_date', 'pmc_cited_by_count', 'title']]
    .to_csv('data/pubmed/articles.tsv.xz', sep='\t', index=False)
)
# Write author dataframe to TSV
author_df.to_csv('data/pubmed/authors.tsv.xz', sep='\t', index=False)

# Write affiliation dataframe to TSV
affiliation_df.to_csv('data/pubmed/affiliations.tsv.xz', sep='\t', index=False)

# %%
# PubMed articles in PMC by journal
article_df.journal.value_counts()
# Out:
# PLoS One                           7755
# Methods Mol Biol                   5440
# Bioinformatics                     5073
# J Proteome Res                     4433
# BMC Genomics                       4086
#                                    ...
# Int J Drug Policy                     1
# J Sex Res                             1
# Int J Nurs Stud                       1
# United European Gastroenterol J       1
# Gerodontology                         1
# Name: journal, Length: 4300, dtype: int64

# %%
# PubMed articles in PMC by journal
pandas.crosstab(article_df.pmcid.notna(), article_df.journal)
# Out:
# journal  A A Case Rep  AACN Adv Crit Care  AACN Clin Issues  AAOHN J  AAPS J  \
# pmcid
# False               1                   6                 1        1       5
# True                0                   0                 1        0      24
#
# journal  AAPS PharmSci  ABNF J  ACS Appl Mater Interfaces  ACS Chem Biol  \
# pmcid
# False                1       0                         11             89
# True                 2       1                          1             84
#
# journal  ACS Chem Neurosci  ...  Zoo Biol  Zool Res  Zoolog Sci  \
# pmcid                       ...
# False                    8  ...         2         0          15
# True                    17  ...         0         4           0
#
# journal  Zoology (Jena)  Zoonoses Public Health  Zootaxa  Zygote  eNeuro  \
# pmcid
# False                 1                       2        9       2       0
# True                  0                       0        0       0       8
#
# journal  mBio  mSphere
# pmcid
# False       0        0
# True      204       37
#
# [2 rows x 4300 columns]

# %%
# articles without a publication date
article_df[article_df.publication_date.isna()]
# Out:
#             pmid       pmcid                                         doi  \
# 7        7513103        None                                        None
# 34       7764291        None                                        None
# 35       7764293        None                                        None
# 54       7856962        None                                        None
# 62       7965253        None          10.1111/j.1552-6909.1994.tb01909.x
# ...          ...         ...                                         ...
# 178813  31808361  PMC6900616                    10.1177/1533033819892260
# 179500  31898667        None                    10.4103/jcrt.jcrt_866_18
# 179614  32053766        None                                        None
# 179647  32421967        None           10.1615/critrevimmunol.2019033126
# 179648  32422010        None  10.1615/critreveukaryotgeneexpr.2019030785
#
#                                journal journal_nlm_id  \
# 7                       Turk J Pediatr        0417505
# 34                Australas Biotechnol        9113681
# 35                Australas Biotechnol        9113681
# 54                            Am Nurse        7506499
# 62      J Obstet Gynecol Neonatal Nurs        8503123
# ...                                ...            ...
# 178813        Technol Cancer Res Treat      101140941
# 179500               J Cancer Res Ther      101249598
# 179614                      Discov Med      101250006
# 179647                Crit Rev Immunol        8914819
# 179648     Crit Rev Eukaryot Gene Expr        9007261
#
#                                                     title publication_date  \
# 7       Child health, the genome project and phenylket...             None
# 34               Some ethical issues in genetic medicine.             None
# 35                  Legal rights and genetic engineering.             None
# 54      Survey assesses RN management of genetic infor...             None
# 62                                    The genome project.             None
# ...                                                   ...              ...
# 178813  Bioinformatics Analysis of Expression and Alte...             None
# 179500  Regulation of HMGA2 and KRAS genes in epitheli...             None
# 179614  Translating cancer genomics for precision onco...             None
# 179647  Pathophysiology, Etiology, Epidemiology of Typ...             None
# 179648  Bioinformatics Approaches to Explore the Phylo...             None
#
#                                                   authors  pmc_cited_by_count
# 7       [{'fore_name': 'C R', 'last_name': 'Scriver', ...                   0
# 34      [{'fore_name': 'N A', 'last_name': 'Tonti-Fili...                   0
# 35      [{'fore_name': 'N', 'last_name': 'Stoianoff', ...                   0
# 54      [{'fore_name': 'C', 'last_name': 'Scanlon', 'a...                   0
# 62      [{'fore_name': 'B S', 'last_name': 'Raff', 'af...                   0
# ...                                                   ...                 ...
# 178813  [{'fore_name': 'Yong-Zi', 'last_name': 'Chen',...                   0
# 179500  [{'fore_name': 'Tuba', 'last_name': 'Gunel', '...                   1
# 179614  [{'fore_name': 'Philipp K', 'last_name': 'Habe...                   0
# 179647  [{'fore_name': 'Begum', 'last_name': 'Dariya',...                   0
# 179648  [{'fore_name': 'Farwa', 'last_name': 'Jabbir',...                   0
#
# [2868 rows x 9 columns]

# %%
# article proportions by date precision
article_df.publication_date.str.len().value_counts()
# Out:
# 10.0    138089
# 7.0      24915
# 4.0      13784
# Name: publication_date, dtype: int64
