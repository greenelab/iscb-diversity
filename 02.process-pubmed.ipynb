# %% [markdown]
# # Extract a dataframe of PubMed articles from efetch XML results

# %%
import collections
import itertools
import pathlib
import pandas
from pubmedpy.xml import iter_extract_elems
from pubmedpy.efetch import extract_all

# %%
# Create a generator of XML PubmedArticle elements
article_elems = itertools.chain.from_iterable(
    iter_extract_elems(path, tag='PubmedArticle')
    for path in sorted(pathlib.Path('data/pubmed/efetch').glob('*.xml.xz'))
)

# %%
articles = list()
for elem in article_elems:
    # Example efetch XML for <PubmedArticle> at https://github.com/dhimmel/pubmedpy/blob/f554a06e13e24d661dc5ff93ad07179fb3d7f0af/pubmedpy/data/efetch.xml
    articles.append(extract_all(elem))
len(articles)
# Out:
# 29755

# %%
article_df = pandas.DataFrame(articles)
article_df.pmid = article_df.pmid.astype(int)
article_df = article_df.sort_values('pmid')
article_df.sample(n=20, random_state=0).sort_values('pmid')
# Out:
#            pmid       pmcid                                     doi  \
# 10363  12386006        None  10.1093/bioinformatics/18.suppl_2.s219
# 11179  14990457        None           10.1093/bioinformatics/btg461
# 11522  15284101        None           10.1093/bioinformatics/bth439
# 13972  18434343        None           10.1093/bioinformatics/btn200
# 3002   19732451  PMC2746223                10.1186/1471-2105-10-280
# 3566   20429880  PMC2882390                10.1186/1471-2105-11-215
# 15775  21088027  PMC3018811           10.1093/bioinformatics/btq644
# 4085   21235786  PMC3025837                 10.1186/1471-2105-12-21
# 4138   21342552  PMC3044277             10.1186/1471-2105-12-s1-s22
# 25269  22496629  PMC3320577            10.1371/journal.pcbi.1002443
# 5087   22901087  PMC3372456              10.1186/1471-2105-13-s9-s2
# 25927  23840181  PMC3688693            10.1371/journal.pcbi.1003107
# 26009  24009490  PMC3757116            10.1371/journal.pcbi.1003190
# 26228  24453956  PMC3894161            10.1371/journal.pcbi.1003429
# 18373  24932001  PMC4058922           10.1093/bioinformatics/btu295
# 18629  25282641        None           10.1093/bioinformatics/btu656
# 19251  26198106        None           10.1093/bioinformatics/btv420
# 20911  28968689  PMC5870547           10.1093/bioinformatics/btx547
# 8229   29589560  PMC5872534               10.1186/s12859-018-2061-1
# 21463  29617954        None           10.1093/bioinformatics/bty196
#
#                   journal journal_nlm_id  \
# 10363      Bioinformatics        9808944
# 11179      Bioinformatics        9808944
# 11522      Bioinformatics        9808944
# 13972      Bioinformatics        9808944
# 3002   BMC Bioinformatics      100965194
# 3566   BMC Bioinformatics      100965194
# 15775      Bioinformatics        9808944
# 4085   BMC Bioinformatics      100965194
# 4138   BMC Bioinformatics      100965194
# 25269    PLoS Comput Biol      101238922
# 5087   BMC Bioinformatics      100965194
# 25927    PLoS Comput Biol      101238922
# 26009    PLoS Comput Biol      101238922
# 26228    PLoS Comput Biol      101238922
# 18373      Bioinformatics        9808944
# 18629      Bioinformatics        9808944
# 19251      Bioinformatics        9808944
# 20911      Bioinformatics        9808944
# 8229   BMC Bioinformatics      100965194
# 21463      Bioinformatics        9808944
#
#                                                    title publication_date  \
# 10363  BioMiner--modeling, analyzing, and visualizing...             2002
# 11179  Support vector machine classification on the web.       2004-01-22
# 11522  Primer design and marker clustering for multip...       2004-07-29
# 13972                A global pathway crosstalk network.       2008-04-23
# 3002   EDGE(3): a web-based solution for management a...       2009-09-04
# 3566   PoGO: Prediction of Gene Ontology terms for fu...       2010-04-29
# 15775  GPU-BLAST: using graphics processors to accele...       2010-11-18
# 4085   NClassG+: A classifier for non-classically sec...       2011-01-14
# 4138   Motif-All: discovering all phosphorylation mot...       2011-02-15
# 25269  Replication fork polarity gradients revealed b...       2012-04-05
# 5087   Modeling and mining term association for impro...       2012-06-11
# 25927  Bacteria-human somatic cell lateral gene trans...       2013-06-20
# 26009  A general model for toxin-antitoxin module dyn...       2013-08-29
# 26228  Phylogenetic Gaussian process model for the in...       2014-01-16
# 18373  Accurate viral population assembly from ultra-...       2014-06-15
# 18629  CompMap: a reference-based compression program...       2014-10-04
# 19251  CEMAsuite: open source degenerate PCR primer d...       2015-07-20
# 20911  Snaptron: querying splicing patterns across te...       2018-01-01
# 8229   Simulating variance heterogeneity in quantitat...       2018-03-21
# 21463  AGORA: organellar genome annotation from the a...       2018-08-01
#
#                                                  authors
# 10363  [{'fore_name': 'M', 'last_name': 'Sirava', 'af...
# 11179  [{'fore_name': 'Paul', 'last_name': 'Pavlidis'...
# 11522  [{'fore_name': 'Anton', 'last_name': 'Yuryev',...
# 13972  [{'fore_name': 'Yong', 'last_name': 'Li', 'aff...
# 3002   [{'fore_name': 'Aaron L', 'last_name': 'Vollra...
# 3566   [{'fore_name': 'Jaehee', 'last_name': 'Jung', ...
# 15775  [{'fore_name': 'Panagiotis D', 'last_name': 'V...
# 4085   [{'fore_name': 'Daniel', 'last_name': 'Restrep...
# 4138   [{'fore_name': 'Zengyou', 'last_name': 'He', '...
# 25269  [{'fore_name': 'Antoine', 'last_name': 'Baker'...
# 5087   [{'fore_name': 'Qinmin', 'last_name': 'Hu', 'a...
# 25927  [{'fore_name': 'David R', 'last_name': 'Riley'...
# 26009  [{'fore_name': 'Lendert', 'last_name': 'Gelens...
# 26228  [{'fore_name': 'Yi-Fei', 'last_name': 'Huang',...
# 18373  [{'fore_name': 'Serghei', 'last_name': 'Mangul...
# 18629  [{'fore_name': 'Zexuan', 'last_name': 'Zhu', '...
# 19251  [{'fore_name': 'Courtney E', 'last_name': 'Lan...
# 20911  [{'fore_name': 'Christopher', 'last_name': 'Wi...
# 8229   [{'fore_name': 'Ahmad', 'last_name': 'Al Kawam...
# 21463  [{'fore_name': 'Jaehee', 'last_name': 'Jung', ...

# %%
author_rows = list()
affiliation_rows = list()
for pmid, authors in zip(article_df.pmid, article_df.authors):
    for i, author in enumerate(authors):
        row_template = {'pmid': pmid, 'position': i + 1}
        row = row_template.copy()
        row.update(author)
        row['reverse_position'] = len(authors) - i
        for affiliation in row.pop('affiliations'):
            affiliation_rows.append(
                {**row_template, "affiliation": affiliation}
            )
        author_rows.append(row)
author_df = pandas.DataFrame(author_rows)
author_df = author_df.sort_values(['pmid', 'position'])
author_df.head()
# Out:
#       pmid  position fore_name  last_name  reverse_position
# 0  9520496         1       B A     Eckman                 7
# 1  9520496         2       J S   Aaronson                 6
# 2  9520496         3       J A  Borkowski                 5
# 3  9520496         4       W J     Bailey                 4
# 4  9520496         5       K O   Elliston                 3

# %%
affiliation_df = pandas.DataFrame(affiliation_rows)
affiliation_df = affiliation_df.sort_values(['pmid', 'position'])
affiliation_df.head()
# Out:
#       pmid  position                                        affiliation
# 0  9520496         1  Department of Bioinformatics, Merck Research L...
# 1  9520497         1  Department of Computer Science, University of ...
# 2  9520498         1                 GIS Infobiogen, Villejuif, France.
# 3  9520499         1  Wadsworth Center for Laboratories and Research...
# 4  9520500         1  Institute for Biomedical Computing, Washington...

# %%
# Number of unique affiliations
affiliation_df.affiliation.nunique()
# Out:
# 50818

# %%
# Write article dataframe to TSV
(
    article_df
    [['pmid', 'pmcid', 'doi', 'journal', 'publication_date', 'title']]
    .to_csv('data/pubmed/articles.tsv.xz', sep='\t', index=False)
)
# Write author dataframe to TSV
author_df.to_csv('data/pubmed/authors.tsv.xz', sep='\t', index=False)

# Write affiliation dataframe to TSV
affiliation_df.to_csv('data/pubmed/affiliations.tsv.xz', sep='\t', index=False)

# %%
# PubMed articles in PMC by journal
article_df.journal.value_counts()
# Out:
# Bioinformatics        13837
# BMC Bioinformatics     9409
# PLoS Comput Biol       6509
# Name: journal, dtype: int64

# %%
# PubMed articles in PMC by journal
pandas.crosstab(article_df.pmcid.notna(), article_df.journal)
# Out:
# journal  BMC Bioinformatics  Bioinformatics  PLoS Comput Biol
# pmcid
# False                    20            8753                18
# True                   9389            5084              6491

# %%
# articles without a publication date
article_df[article_df.publication_date.isna()]
# Out:
#           pmid pmcid                              doi         journal  \
# 9607  10487860  None  10.1093/bioinformatics/15.7.528  Bioinformatics
# 9608  10487861  None  10.1093/bioinformatics/15.7.536  Bioinformatics
# 9609  10487862  None  10.1093/bioinformatics/15.7.544  Bioinformatics
# 9610  10487863  None  10.1093/bioinformatics/15.7.553  Bioinformatics
# 9611  10487864  None  10.1093/bioinformatics/15.7.563  Bioinformatics
# 9612  10487865  None  10.1093/bioinformatics/15.7.578  Bioinformatics
# 9613  10487866  None  10.1093/bioinformatics/15.7.582  Bioinformatics
# 9614  10487867  None  10.1093/bioinformatics/15.7.593  Bioinformatics
# 9615  10487868  None  10.1093/bioinformatics/15.7.607  Bioinformatics
# 9616  10487869  None  10.1093/bioinformatics/15.7.612  Bioinformatics
# 9617  10487870  None  10.1093/bioinformatics/15.7.622  Bioinformatics
# 9618  10487871  None  10.1093/bioinformatics/15.7.631  Bioinformatics
# 9619  10487872  None  10.1093/bioinformatics/15.7.644  Bioinformatics
# 9620  10487873  None  10.1093/bioinformatics/15.7.654  Bioinformatics
# 9621  10487874  None  10.1093/bioinformatics/15.7.669  Bioinformatics
# 9622  10487875  None  10.1093/bioinformatics/15.7.687  Bioinformatics
# 9623  10487876  None  10.1093/bioinformatics/15.7.704  Bioinformatics
# 9624  10487877  None  10.1093/bioinformatics/15.7.713  Bioinformatics
#
#      journal_nlm_id                                              title  \
# 9607        9808944  Evaluation of human-readable annotation in bio...
# 9608        9808944  Complete genomes in WWW Entrez: data represent...
# 9609        9808944  Development of the receptor database (RDB): ap...
# 9610        9808944  Regression trees for analysis of mutational sp...
# 9611        9808944  Identifying DNA and protein patterns with stat...
# 9612        9808944  Analysis of base-pairing potentials between 16...
# 9613        9808944                 Nucleosomal DNA property database.
# 9614        9808944  Genetic control of flower morphogenesis in Ara...
# 9615        9808944  SCPD: a promoter database of the yeast Sacchar...
# 9616        9808944  GeneBuilder: interactive in silico prediction ...
# 9617        9808944  Estimating transcription factor bindability on...
# 9618        9808944  Oligonucleotide frequency matrices addressed t...
# 9619        9808944  Investigating extended regulatory regions of g...
# 9620        9808944  Conformational and physicochemical DNA feature...
# 9621        9808944  Integrated databases and computer systems for ...
# 9622        9808944  Identification of sequence-dependent DNA featu...
# 9623        9808944  Prediction of eukaryotic mRNA translational pr...
# 9624        9808944  Interactive data input into the GeneNet database.
#
#      publication_date                                            authors
# 9607             None  [{'fore_name': 'F', 'last_name': 'Eisenhaber',...
# 9608             None  [{'fore_name': 'T A', 'last_name': 'Tatusova',...
# 9609             None  [{'fore_name': 'K', 'last_name': 'Nakata', 'af...
# 9610             None  [{'fore_name': 'V B', 'last_name': 'Berikov', ...
# 9611             None  [{'fore_name': 'G Z', 'last_name': 'Hertz', 'a...
# 9612             None  [{'fore_name': 'Y', 'last_name': 'Osada', 'aff...
# 9613             None  [{'fore_name': 'V G', 'last_name': 'Levitsky',...
# 9614             None  [{'fore_name': 'L', 'last_name': 'Mendoza', 'a...
# 9615             None  [{'fore_name': 'J', 'last_name': 'Zhu', 'affil...
# 9616             None  [{'fore_name': 'L', 'last_name': 'Milanesi', '...
# 9617             None  [{'fore_name': 'T', 'last_name': 'Tsunoda', 'a...
# 9618             None  [{'fore_name': 'M P', 'last_name': 'Ponomarenk...
# 9619             None  [{'fore_name': 'V N', 'last_name': 'Babenko', ...
# 9620             None  [{'fore_name': 'J V', 'last_name': 'Ponomarenk...
# 9621             None  [{'fore_name': 'N A', 'last_name': 'Kolchanov'...
# 9622             None  [{'fore_name': 'M P', 'last_name': 'Ponomarenk...
# 9623             None  [{'fore_name': 'A V', 'last_name': 'Kochetov',...
# 9624             None  [{'fore_name': 'F A', 'last_name': 'Kolpakov',...

# %%
# article proportions by date precision
article_df.publication_date.str.len().value_counts()
# Out:
# 10.0    28423
# 7.0      1002
# 4.0       312
# Name: publication_date, dtype: int64
