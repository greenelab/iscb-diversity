# %% [markdown]
# # Extract a dataframe of PubMed articles from efetch XML results

# %%
import collections
import itertools
import pathlib
import pandas
from pubmedpy.xml import iter_extract_elems
from pubmedpy.efetch import extract_all

# %%
# Create a generator of XML PubmedArticle elements
article_elems = itertools.chain.from_iterable(
    iter_extract_elems(path, tag='PubmedArticle')
    for path in sorted(pathlib.Path('data/pubmed/efetch').glob('*.xml.xz'))
)

# %%
articles = list()
for elem in article_elems:
    # Example efetch XML for <PubmedArticle> at https://github.com/dhimmel/pubmedpy/blob/f554a06e13e24d661dc5ff93ad07179fb3d7f0af/pubmedpy/data/efetch.xml
    articles.append(extract_all(elem))
len(articles)
# Out:
# 29624

# %%
article_df = pandas.DataFrame(articles)
article_df.pmid = article_df.pmid.astype(int)
article_df = article_df.sort_values('pmid')
#article_df['last_author'] = article_df.authors.map(lambda x: '{fore_name} {last_name}'.format(**x[-1]) if x else None)
# article_df['last_author_fore_name'] = article_df.authors.map(lambda x: x[-1]['fore_name'] if x else None)
# article_df['last_author_last_name'] = article_df.authors.map(lambda x: x[-1]['last_name'] if x else None)
# article_df['n_authors'] = article_df.authors.map(len)
article_df.sample(n=20, random_state=0).sort_values('pmid')
# Out:
#            pmid       pmcid                               doi  \
# 9647   11159308        None  10.1093/bioinformatics/16.11.968
# 11357  15284100        None     10.1093/bioinformatics/bth440
# 11827  15802286        None     10.1093/bioinformatics/bti420
# 23353  17319737  PMC1808025      10.1371/journal.pcbi.0030020
# 13614  18056063        None     10.1093/bioinformatics/btm592
# 2944   19615046  PMC2720391          10.1186/1471-2105-10-222
# 14894  19880367  PMC2796817     10.1093/bioinformatics/btp615
# 3444   20175920  PMC3098051          10.1186/1471-2105-11-100
# 3707   20576157  PMC2911458          10.1186/1471-2105-11-347
# 4320   21612626  PMC3123608          10.1186/1471-2105-12-201
# 25054  22319429  PMC3271023      10.1371/journal.pcbi.1002355
# 17155  23349212        None     10.1093/bioinformatics/bts729
# 25986  24244119  PMC3828139      10.1371/journal.pcbi.1003289
# 5842   24341432  PMC3878503          10.1186/1471-2105-14-365
# 5944   24564482  PMC4016020        10.1186/1471-2105-15-s1-s9
# 18909  25953799        None     10.1093/bioinformatics/btv283
# 7446   27923364  PMC5142268         10.1186/s12859-016-1401-2
# 21360  29718113        None     10.1093/bioinformatics/bty327
# 29244  31095556  PMC6541306      10.1371/journal.pcbi.1006999
# 29392  31404059  PMC6742410      10.1371/journal.pcbi.1007223
#
#                   journal journal_nlm_id  \
# 9647       Bioinformatics        9808944
# 11357      Bioinformatics        9808944
# 11827      Bioinformatics        9808944
# 23353    PLoS Comput Biol      101238922
# 13614      Bioinformatics        9808944
# 2944   BMC Bioinformatics      100965194
# 14894      Bioinformatics        9808944
# 3444   BMC Bioinformatics      100965194
# 3707   BMC Bioinformatics      100965194
# 4320   BMC Bioinformatics      100965194
# 25054    PLoS Comput Biol      101238922
# 17155      Bioinformatics        9808944
# 25986    PLoS Comput Biol      101238922
# 5842   BMC Bioinformatics      100965194
# 5944   BMC Bioinformatics      100965194
# 18909      Bioinformatics        9808944
# 7446   BMC Bioinformatics      100965194
# 21360      Bioinformatics        9808944
# 29244    PLoS Comput Biol      101238922
# 29392    PLoS Comput Biol      101238922
#
#                                                    title publication_date  \
# 9647   Short interrupted palindromes on the extrageni...          2000-11
# 11357  Accurate detection of aneuploidies in array CG...       2004-07-29
# 11827  A comprehensive and non-redundant database of ...       2005-03-31
# 23353  Improving the Caenorhabditis elegans genome an...       2006-12-21
# 13614  Model-based deconvolution of genome-wide DNA b...       2007-12-01
# 2944   PCI-SS: MISO dynamic nonlinear protein seconda...       2009-07-17
# 14894  inGAP: an integrated next-generation genome an...       2009-10-30
# 3444   DraGnET: software for storing, managing and an...       2010-02-22
# 3707   Local alignment of generalized k-base encoded ...       2010-06-24
# 4320   CAPL: an efficient association software packag...       2011-05-25
# 25054  In silico experimentation of glioma microenvir...       2012-02-02
# 17155  Graphlet-based measures are suitable for biolo...       2013-01-23
# 25986            Dynamical adaptation in photoreceptors.       2013-11-14
# 5842   Network-based differential gene expression ana...       2013-12-17
# 5944   Toolboxes for a standardised and systematic st...       2014-01-10
# 18909  IonGAP: integrative bacterial genome analysis ...       2015-05-06
# 7446   PCAN: phenotype consensus analysis to support ...       2016-12-07
# 21360  Prediction of lncRNA-disease associations base...       2018-10-01
# 29244  Amplifying the redistribution of somato-dendri...       2019-05-16
# 29392  Aggressive or moderate drug therapy for infect...       2019-08-12
#
#                                                  authors
# 9647   [{'fore_name': 'A T', 'last_name': 'Vasconcelo...
# 11357  [{'fore_name': 'Chad L', 'last_name': 'Myers',...
# 11827  [{'fore_name': 'Guoying', 'last_name': 'Qi', '...
# 23353  [{'fore_name': 'Gunnar', 'last_name': 'Rätsch'...
# 13614  [{'fore_name': 'David J', 'last_name': 'Reiss'...
# 2944   [{'fore_name': 'James R', 'last_name': 'Green'...
# 14894  [{'fore_name': 'Ji', 'last_name': 'Qi', 'affil...
# 3444   [{'fore_name': 'Stacy', 'last_name': 'Duncan',...
# 3707   [{'fore_name': 'Nils', 'last_name': 'Homer', '...
# 4320   [{'fore_name': 'Ren-Hua', 'last_name': 'Chung'...
# 25054  [{'fore_name': 'Yu', 'last_name': 'Wu', 'affil...
# 17155  [{'fore_name': 'Wayne', 'last_name': 'Hayes', ...
# 25986  [{'fore_name': 'Damon A', 'last_name': 'Clark'...
# 5842   [{'fore_name': 'Chao', 'last_name': 'Wu', 'aff...
# 5944   [{'fore_name': 'Matthew P', 'last_name': 'Camp...
# 18909  [{'fore_name': 'Adrian', 'last_name': 'Baez-Or...
# 7446   [{'fore_name': 'Patrice', 'last_name': 'Godard...
# 21360  [{'fore_name': 'Chengqian', 'last_name': 'Lu',...
# 29244  [{'fore_name': 'Loreen', 'last_name': 'Hertäg'...
# 29392  [{'fore_name': 'Jérémie', 'last_name': 'Scire'...

# %%
author_rows = list()
for pmid, authors in zip(article_df.pmid, article_df.authors):
    for i, author in enumerate(authors):
        row = {'pmid': pmid, 'position': i + 1}
        row.update(author)
        row['reverse_position'] = len(authors) - i
        row.pop('affiliations')
        author_rows.append(row)
author_df = pandas.DataFrame(author_rows)
author_df = author_df.sort_values(['pmid', 'position'])
author_df.head()
# Out:
#        pmid  position fore_name   last_name  reverse_position
# 0  10068688         1         C     Médigue                 4
# 1  10068688         2         F  Rechenmann                 3
# 2  10068688         3         A     Danchin                 2
# 3  10068688         4         A       Viari                 1
# 4  10068689         1         W    Kasprzak                 2

# %%
# Write article dataframe to TSV
(
    article_df
    [['pmid', 'pmcid', 'doi', 'journal', 'publication_date', 'title']]
    .to_csv('data/pubmed/articles.tsv.xz', sep='\t', index=False)
)
# Write author dataframe to TSV
author_df.to_csv('data/pubmed/authors.tsv.xz', sep='\t', index=False)

# %%
# PubMed articles in PMC by journal
article_df.journal.value_counts()
# Out:
# Bioinformatics        13743
# BMC Bioinformatics     9372
# PLoS Comput Biol       6509
# Name: journal, dtype: int64

# %%
# PubMed articles in PMC by journal
pandas.crosstab(article_df.pmcid.notna(), article_df.journal)
# Out:
# journal  BMC Bioinformatics  Bioinformatics  PLoS Comput Biol
# pmcid
# False                    99            8671                51
# True                   9273            5072              6458

# %%
# articles without a publication date
article_df[article_df.publication_date.isna()]
# Out:
#           pmid pmcid                              doi         journal  \
# 9443  10487860  None  10.1093/bioinformatics/15.7.528  Bioinformatics
# 9444  10487861  None  10.1093/bioinformatics/15.7.536  Bioinformatics
# 9445  10487862  None  10.1093/bioinformatics/15.7.544  Bioinformatics
# 9446  10487863  None  10.1093/bioinformatics/15.7.553  Bioinformatics
# 9447  10487864  None  10.1093/bioinformatics/15.7.563  Bioinformatics
# 9448  10487865  None  10.1093/bioinformatics/15.7.578  Bioinformatics
# 9449  10487866  None  10.1093/bioinformatics/15.7.582  Bioinformatics
# 9450  10487867  None  10.1093/bioinformatics/15.7.593  Bioinformatics
# 9451  10487868  None  10.1093/bioinformatics/15.7.607  Bioinformatics
# 9452  10487869  None  10.1093/bioinformatics/15.7.612  Bioinformatics
# 9453  10487870  None  10.1093/bioinformatics/15.7.622  Bioinformatics
# 9454  10487871  None  10.1093/bioinformatics/15.7.631  Bioinformatics
# 9455  10487872  None  10.1093/bioinformatics/15.7.644  Bioinformatics
# 9456  10487873  None  10.1093/bioinformatics/15.7.654  Bioinformatics
# 9457  10487874  None  10.1093/bioinformatics/15.7.669  Bioinformatics
# 9458  10487875  None  10.1093/bioinformatics/15.7.687  Bioinformatics
# 9459  10487876  None  10.1093/bioinformatics/15.7.704  Bioinformatics
# 9460  10487877  None  10.1093/bioinformatics/15.7.713  Bioinformatics
#
#      journal_nlm_id                                              title  \
# 9443        9808944  Evaluation of human-readable annotation in bio...
# 9444        9808944  Complete genomes in WWW Entrez: data represent...
# 9445        9808944  Development of the receptor database (RDB): ap...
# 9446        9808944  Regression trees for analysis of mutational sp...
# 9447        9808944  Identifying DNA and protein patterns with stat...
# 9448        9808944  Analysis of base-pairing potentials between 16...
# 9449        9808944                 Nucleosomal DNA property database.
# 9450        9808944  Genetic control of flower morphogenesis in Ara...
# 9451        9808944  SCPD: a promoter database of the yeast Sacchar...
# 9452        9808944  GeneBuilder: interactive in silico prediction ...
# 9453        9808944  Estimating transcription factor bindability on...
# 9454        9808944  Oligonucleotide frequency matrices addressed t...
# 9455        9808944  Investigating extended regulatory regions of g...
# 9456        9808944  Conformational and physicochemical DNA feature...
# 9457        9808944  Integrated databases and computer systems for ...
# 9458        9808944  Identification of sequence-dependent DNA featu...
# 9459        9808944  Prediction of eukaryotic mRNA translational pr...
# 9460        9808944  Interactive data input into the GeneNet database.
#
#      publication_date                                            authors
# 9443             None  [{'fore_name': 'F', 'last_name': 'Eisenhaber',...
# 9444             None  [{'fore_name': 'T A', 'last_name': 'Tatusova',...
# 9445             None  [{'fore_name': 'K', 'last_name': 'Nakata', 'af...
# 9446             None  [{'fore_name': 'V B', 'last_name': 'Berikov', ...
# 9447             None  [{'fore_name': 'G Z', 'last_name': 'Hertz', 'a...
# 9448             None  [{'fore_name': 'Y', 'last_name': 'Osada', 'aff...
# 9449             None  [{'fore_name': 'V G', 'last_name': 'Levitsky',...
# 9450             None  [{'fore_name': 'L', 'last_name': 'Mendoza', 'a...
# 9451             None  [{'fore_name': 'J', 'last_name': 'Zhu', 'affil...
# 9452             None  [{'fore_name': 'L', 'last_name': 'Milanesi', '...
# 9453             None  [{'fore_name': 'T', 'last_name': 'Tsunoda', 'a...
# 9454             None  [{'fore_name': 'M P', 'last_name': 'Ponomarenk...
# 9455             None  [{'fore_name': 'V N', 'last_name': 'Babenko', ...
# 9456             None  [{'fore_name': 'J V', 'last_name': 'Ponomarenk...
# 9457             None  [{'fore_name': 'N A', 'last_name': 'Kolchanov'...
# 9458             None  [{'fore_name': 'M P', 'last_name': 'Ponomarenk...
# 9459             None  [{'fore_name': 'A V', 'last_name': 'Kochetov',...
# 9460             None  [{'fore_name': 'F A', 'last_name': 'Kolpakov',...

# %%
# article proportions by date precision
article_df.publication_date.str.len().value_counts()
# Out:
# 10.0    28419
# 7.0       990
# 4.0       197
# Name: publication_date, dtype: int64
