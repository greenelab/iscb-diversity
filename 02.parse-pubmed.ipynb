# %% [markdown]
# https://github.com/dhimmel/delays/blob/master/process-esummary.ipynb
#
# TODO update with https://github.com/dhimmel/delays/blob/upgrade/pydelays/xml_to_dates.py

# %%
import collections
import itertools
import pathlib
import pandas
from pubmedpy.xml import iter_extract_elems
from pubmedpy.efetch import extract_all

# %%
# Create a generator of XML PubmedArticle elements
article_elems = itertools.chain.from_iterable(
    iter_extract_elems(path, tag='PubmedArticle')
    for path in sorted(pathlib.Path('data/pubmed/efetch').glob('*.xml.xz'))
)

# %%
articles = list()
for elem in article_elems:
    # Example efetch XML for <PubmedArticle> at https://github.com/dhimmel/pubmedpy/blob/f554a06e13e24d661dc5ff93ad07179fb3d7f0af/pubmedpy/data/efetch.xml
    articles.append(extract_all(elem))
len(articles)
# Out:
# 28436

# %%
article_df = pandas.DataFrame(articles)
article_df.pmid = article_df.pmid.astype(int)
article_df = article_df.sort_values('pmid')
article_df.sample(n=20, random_state=0).sort_values('pmid')
# Out:
#            pmid       pmcid                            doi  \
# 67     12854978   PMC166169         10.1186/1471-2105-4-29
# 10332  15073026        None  10.1093/bioinformatics/bth174
# 279    15527510   PMC533868        10.1186/1471-2105-5-176
# 330    15673474   PMC548130         10.1186/1471-2105-6-18
# 11502  16303795        None  10.1093/bioinformatics/bti793
# 1265   17217507  PMC1780126     10.1186/1471-2105-7-s4-s15
# 1574   17594507  PMC1925121        10.1186/1471-2105-8-223
# 1736   17931407  PMC2148069        10.1186/1471-2105-8-380
# 12780  18006552        None  10.1093/bioinformatics/btm522
# 22770  19008937  PMC2570617   10.1371/journal.pcbi.1000221
# 2701   19208178  PMC2648762    10.1186/1471-2105-10-s1-s73
# 3406   20128916  PMC2829012        10.1186/1471-2105-11-72
# 14752  20929912        None  10.1093/bioinformatics/btq567
# 4723   22305354  PMC3298499        10.1186/1471-2105-13-24
# 24051  22379410  PMC3269904   10.1371/journal.pcbi.1002352
# 7193   27170106  PMC4864913      10.1186/s12859-016-1066-x
# 19116  27515741  PMC5181538  10.1093/bioinformatics/btw524
# 7732   28361710  PMC5374685      10.1186/s12859-017-1466-6
# 21936  31392316        None  10.1093/bioinformatics/btz627
# 9089   31438841  PMC6704681      10.1186/s12859-019-3024-x
#
#                   journal journal_nlm_id  \
# 67     BMC Bioinformatics      100965194
# 10332      Bioinformatics        9808944
# 279    BMC Bioinformatics      100965194
# 330    BMC Bioinformatics      100965194
# 11502      Bioinformatics        9808944
# 1265   BMC Bioinformatics      100965194
# 1574   BMC Bioinformatics      100965194
# 1736   BMC Bioinformatics      100965194
# 12780      Bioinformatics        9808944
# 22770    PLoS Comput Biol      101238922
# 2701   BMC Bioinformatics      100965194
# 3406   BMC Bioinformatics      100965194
# 14752      Bioinformatics        9808944
# 4723   BMC Bioinformatics      100965194
# 24051    PLoS Comput Biol      101238922
# 7193   BMC Bioinformatics      100965194
# 19116      Bioinformatics        9808944
# 7732   BMC Bioinformatics      100965194
# 21936      Bioinformatics        9808944
# 9089   BMC Bioinformatics      100965194
#
#                                                    title publication_date  \
# 67     MatGAT: an application that generates similari...       2003-07-10
# 10332  ArrayNorm: comprehensive normalization and ana...       2004-04-08
# 279    ESTIMA, a tool for EST management in a multi-p...       2004-11-04
# 330    Identification of novel prognostic markers in ...       2005-01-26
# 11502  Describing ancient horizontal gene transfers a...       2005-11-22
# 1265   Parallelization of multicategory support vecto...       2006-12-12
# 1574   High-throughput identification of interacting ...       2007-06-27
# 1736   Detailed estimation of bioinformatics predicti...       2007-10-11
# 12780  Detecting high-order interactions of single nu...       2007-11-15
# 22770  Polar or apolar--the role of polarity for urea...       2008-11-14
# 2701   PCA-based population structure inference with ...       2009-01-30
# 3406   Bias correction and Bayesian analysis of aggre...       2010-02-03
# 14752  Pathway Activity Profiling (PAPi): from the me...       2010-10-06
# 4723   Independent Principal Component Analysis for b...       2012-02-03
# 24051  Dynamic modelling under uncertainty: the case ...       2012-01-19
# 7193   A gene-signature progression approach to ident...       2016-05-11
# 19116            Multivariate Welch t-test on distances.       2016-08-11
# 7732   A framework for space-efficient read clusterin...       2017-03-14
# 21936  scHinter: Imputing dropout events for single-c...       2019-08-08
# 9089   Measuring similarity between gene interaction ...       2019-08-22
#
#                                                  authors
# 67     [{'fore_name': 'James J', 'last_name': 'Campan...
# 10332  [{'fore_name': 'R', 'last_name': 'Pieler', 'af...
# 279    [{'fore_name': 'Charu G', 'last_name': 'Kumar'...
# 330    [{'fore_name': 'Rifat A', 'last_name': 'Hamoud...
# 11502  [{'fore_name': 'F', 'last_name': 'Collyn', 'af...
# 1265   [{'fore_name': 'Chaoyang', 'last_name': 'Zhang...
# 1574   [{'fore_name': 'Jo-Lan', 'last_name': 'Chung',...
# 1736   [{'fore_name': 'Oliviero', 'last_name': 'Carug...
# 12780  [{'fore_name': 'Robin', 'last_name': 'Nunkesse...
# 22770  [{'fore_name': 'Martin C', 'last_name': 'Stump...
# 2701   [{'fore_name': 'Chih', 'last_name': 'Lee', 'af...
# 3406   [{'fore_name': 'Russell L', 'last_name': 'Zare...
# 14752  [{'fore_name': 'Raphael B M', 'last_name': 'Ag...
# 4723   [{'fore_name': 'Fangzhou', 'last_name': 'Yao',...
# 24051  [{'fore_name': 'Fiona', 'last_name': 'Achcar',...
# 7193   [{'fore_name': 'Qing', 'last_name': 'Wen', 'af...
# 19116  [{'fore_name': 'Alexander V', 'last_name': 'Al...
# 7732   [{'fore_name': 'Jarno', 'last_name': 'Alanko',...
# 21936  [{'fore_name': 'Pengchao', 'last_name': 'Ye', ...
# 9089   [{'fore_name': 'Joëlle', 'last_name': 'Barido-...

# %%
# PubMed articles in PMC by journal
article_df.journal.value_counts()
# Out:
# Bioinformatics        12963
# BMC Bioinformatics     9124
# PLoS Comput Biol       6349
# Name: journal, dtype: int64

# %%
# PubMed articles in PMC by journal
pandas.crosstab(article_df.pmcid.notna(), article_df.journal)
# Out:
# journal  BMC Bioinformatics  Bioinformatics  PLoS Comput Biol
# pmcid
# False                    25            8166                52
# True                   9099            4797              6297

# %%
# articles without a publication date
article_df[article_df.publication_date.isna()]
# Out:
# Empty DataFrame
# Columns: [pmid, pmcid, doi, journal, journal_nlm_id, title, publication_date, authors]
# Index: []

# %%
# article proportions by date precision
article_df.publication_date.str.len().value_counts()
# Out:
# 10    27767
# 7       510
# 4       159
# Name: publication_date, dtype: int64
